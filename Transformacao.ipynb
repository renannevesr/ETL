# %% [markdown]
# <a href="https://colab.research.google.com/github/renannevesr/ETL/blob/main/Transformacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandera
import pandas as pd
import pandera as pa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
valores_ausentes = ['***','###!', '####', '****', '*****', 'NULL','**']
df =pd.read_csv("/content/drive/MyDrive/Python/ocorrencia.csv", sep =";", parse_dates = ['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  52242               52242                INCIDENTE
# ...

# %%
df.drop(columns=['codigo_ocorrencia4', 'codigo_ocorrencia3','ocorrencia_latitude', 'ocorrencia_longitude', 'ocorrencia_pais', 'investigacao_aeronave_liberada','investigacao_status',	'divulgacao_relatorio_numero',	'divulgacao_relatorio_publicado',	'divulgacao_dia_publicacao','total_aeronaves_envolvidas', 'ocorrencia_saida_pista'], inplace = True)

# %%
#validação pandera
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2), nullable= True),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable= True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }

)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                    ACIDENTE         GUARULHOS            SP
# ...

# %%
df.loc[df.ocorrencia_uf.isnull()]
#filtro = df.ocorrencia_uf.isnull()
#df.loc[filtro]
#df.count()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1099              49474               49474               49474
# 4728              79956               79956               79956
#
#      ocorrencia_classificacao     ocorrencia_cidade ocorrencia_uf  \
# 1099                 ACIDENTE  ÁGUAS INTERNACIONAIS           NaN
# 4728                 ACIDENTE      NÃO IDENTIFICADA           NaN
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 1099                  NaN     2013-09-02        02:54:00                    0
# 4728                  NaN     2021-02-26        11:00:00                    0

# %%
#ocorrências com mais de 10 recomendações 
filtro = df.total_recomendacoes>10
df.loc[filtro,['ocorrencia_cidade']]
# Out:
#      ocorrencia_cidade
# 844           BRASÍLIA
# 1669            SANTOS
# 2804           VITÓRIA

# %%
#ocorrências cuja classificação == incidente grave e o estado == sp
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf =='SP'
df.loc[filtro1&filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6                 50713               50713               50713
# 78                45598               45598               45598
# 86                45653               45653               45653
# 91                45599               45599               45599
# 140               45651               45651               45651
# ...                 ...                 ...                 ...
# 4954              80200               80200               80200
# 4980              80238               80238               80238
# 5003              80265               80265               80265
# 5098              80382               80382               80382
# 5158              80454               80454               80454
#
#      ocorrencia_classificacao  ocorrencia_cidade ocorrencia_uf  \
# 6             INCIDENTE GRAVE           CAMPINAS            SP
# 78            INCIDENTE GRAVE  BRAGANÇA PAULISTA            SP
# ...

# %%
filtro1 = df.ocorrencia_classificacao.isin( ['INCIDENTE GRAVE','INCIDENTE'])
filtro2 = df.ocorrencia_uf =='SP'
df.loc[filtro1&filtro2]

# %%
#ocorrencias cuja cidade terminam com MA
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]

# %%
#ocorrencias ano 2015 
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1870              52992               52992               52992
# 1871              52979               52979               52979
# 1872              53073               53073               53073
# 1873              53074               53074               53074
# 1874              52976               52976               52976
# ...                 ...                 ...                 ...
# 2336              60632               60632               60632
# 2337              60600               60600               60600
# 2338              60642               60642               60642
# 2339              60631               60631               60631
# 2340              60649               60649               60649
#
#      ocorrencia_classificacao     ocorrencia_cidade ocorrencia_uf  \
# 1870          INCIDENTE GRAVE              SALVADOR            BA
# ...
